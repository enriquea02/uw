# %% [markdown]
# ## Lecture 3 Sequences, Convergence, and Calculus
# ## Additional References
# | Subject                                           | Reference                                         |
# | ---                                               | ---                                               |
# | | |
#
# ## Notation
#
# ## Language
# ### Sets
# | Math Language             | English Translation                   |
# | ---                       | ---                                   |
# | $ \delta $                | Delta                                 |
# | $ \epsilon $              | Epsilon                               |
#
# ### Functions
# | Math Language             | English Translation                   |
# | ---                       | ---                                   |
# | | |
#
# ## Dictionary
# ### Sets
# | Math Word                 | Definition                                |
# | ---                       | ---                                       |
# | | |
#
# ### Functions
# | Math Word                 | Definition                                        |
# | ---                       | ---                                               |
# | | |
#
#
# ## Notes
# ### Sequences
#
# ### Limits of Functions
# Positive values of $a$ lead to unstable systems | Negative values of $a$ lead to stable systems
# $$ x[n+1] = ax[n] $$
#
# Theorem 3 is a one way statement. Input must be convergent for output to converge, for theorem to hold. <br>
# Theorem 4. Break big funcs to smaller func. <br>
# Good for proofs. Can't prove big func, then prove its components. <br>
# <br>
# Cont func have a small delta output with small delta inputs.<br>
# Proofs. Not real world usage. <br>
# Prove func $\neq$ cont, use non-convergence criterion as couterexample.
# <br>
# Intermediate Value Theorem <br>
# Formal, Google :) <br>
# Informal, iff func is continuous between $x_1$ and $x_2$, then there will be a y for all x inputs between $f(x_1)$ and $f(x_2)$
#
# ### Differentiation
# Differentiation Theorem <br>
# L'Hospital's Rule for 0/0 <br>
# Mean Value Theorem (MVT) <br>
#
# #### Taylor's Theorem
# ### Linear Algebra
#
# ## Questions
# \begin{enumerate}
#     \item \text{Where do you use the trianglue inequality in proof writing typically?}
# \end{enumerate}
# 1. Why does $a$ determine whether a system is stable/unstable? Graph to visualize
# 2. What is the benefit of a continuous function? Why do I care if a function is continuous?
# 3. Are bounds for differentiation $\neq$ cluster point?
# 4. What does $\epsilon$ represent and $\delta$? Do they represent small changes in x and y in a graph?
# 5. Can non-continuous functions be differentiated?
# 6. Why do I care about MVT?
