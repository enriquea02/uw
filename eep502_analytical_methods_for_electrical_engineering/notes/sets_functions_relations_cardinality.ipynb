# %% [markdown]
# # Lecture 2 Sets, Functions, Relations, Cardinality
# ## Notation
# Sets are identified through uppercase letters <br>
#
# ## Language
# ### Sets
# | Math Language             | English Translation                   |
# | ---                       | ---                                   |
# | $ x \isin X $             | x is an element of set X              |
# | $ x \notin X $            | x is not an element of set X          |
# | $ \boldsymbol{U} $        | universal set                         |
# | $ \oplus $                | symmetric difference                  |
# | $ \varnothing $           | empty set                             |
# | $ X \neq \varnothing $    | X is not empty                        |
# | $ \natnums $              | set of natural numbers                |
# | $ \mathbb{N}_0 $          | set of natural numbers including zero |
# | $ \mathbb{Z} $            | set of integers                       |
# | $ \mathbb{Q} $            | set of rational numbers               |
# | $ \reals $                | set of real numbers                   |
# | $ \mathbb{C} $            | set of complex numbers                |
# | $ \Re $                   | real part of a complex                |
# | $ \image $                | imaginary part of a complex           |
#
# ### Functions
# | Math Language             | English Translation                   |
# | ---                       | ---                                   |
# | | |
#
# ## Dictionary
# ### Sets
# | Math Word                 | Definition                                |
# | ---                       | ---                                       |
# | **Set Cardinality**       | size of a set (e.g. 0, ∞, n elements)     |
# | **Roster Notation**       | lists                                     |
# | **Set Builder Notation**  |                                           |
# | **Power Sets**            | all the subsets within a set              |
# | **Tuple**                 | are ordered sets                          |
# | **Union**                 |                                           |
# | **Intersection**          |                                           |
# | **Relative Complement**   |                                           |
#
# ### Functions
# | Math Word                 | Definition                                        |
# | ---                       | ---                                               |
# | **domain**                |                                                   |
# | **target**                | $\boldsymbol{U}$ of all possible function outputs |
# | **range**                 |                                                   |
# | **preimage**              |                                                   |
# | **image**                 |                                                   |
# | **injection**             |                                                   |
# | **one-to-one**            |                                                   |
#
# ## Notes
# ### Sets
# Proofs for sets can be written using ZFC axioms written by Zermelo and Fraenkel <br>
# <br>
# All sets include the $ \varnothing $ subset <br>
# <br>
# $ \mathbb{N} $ in set theory inclues zero, so ignore $ \mathbb{N}_0 $
# $ \mathbb{Z} $ comes from "zahl" (German for number). $ \mathbb{Z} $ includes zero. <br>
# $ \mathbb{Q} $ comes from quotient <br>
# $$ \mathbb{Q} = p/q : p,q \isin \mathbb{Z} \text{ and } q \neq 0 $$
# <br>
# Complex analysis will not be covered in real analysis. For fun, set builder notation for entire set of complex numbers: <br>
#
# $$ \mathbb{C} = x + iy : \text{ x,y } \isin \R $$
#
# $$ \mathbb{Z}_+ != \mathbb{Z}_{++}: \mathbb{Z}_+ \text{ includes non-negative integer range and zero, } \mathbb{Z}_{++} \text{ includes non-negative intergers but not zero } $$
# $$ \mathbb{Z}_{--} == \mathbb{Z}_- : \text{ are same, because zero is not included in negative integer range } $$
#
# #### Applications
# **Cartesian Products** <br>
#
# ### Functions
# Target Set $\geq$ Range Set
#
# ## Questions
# 1. High-level, what is the difference between real analysis and complex analysis?
# 2. Why do we use complex analysis? What are examples?
# 3. How did complex analysis form, why wasn't $ \R $ enough?
